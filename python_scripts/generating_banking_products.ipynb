# %%
import pandas as pd

products = [
    {"product_id": 1, "product_name": "Basic Savings Account", "product_type": "Deposit", "interest_rate": 1.5, "min_balance": 50, "max_balance": None, "fees": 10, "currency": "TTD"},
    {"product_id": 2, "product_name": "Premium Savings Account", "product_type": "Deposit", "interest_rate": 2.0, "min_balance": 5000, "max_balance": None, "fees": 20, "currency": "TTD"},
    {"product_id": 3, "product_name": "Checking Account", "product_type": "Deposit", "interest_rate": 0.5, "min_balance": 0, "max_balance": None, "fees": 15, "currency": "TTD"},
    {"product_id": 4, "product_name": "Personal Loan", "product_type": "Loan", "interest_rate": 10, "min_balance": 1000, "max_balance": 200000, "fees": 0, "currency": "TTD"},
    {"product_id": 5, "product_name": "Home Loan", "product_type": "Loan", "interest_rate": 7, "min_balance": 50000, "max_balance": 1000000, "fees": 0, "currency": "TTD"},
    {"product_id": 6, "product_name": "Credit Card", "product_type": "Credit", "interest_rate": 18, "min_balance": 0, "max_balance": 50000, "fees": 50, "currency": "TTD"},
    {"product_id": 7, "product_name": "Investment Account", "product_type": "Investment", "interest_rate": 5, "min_balance": 1000, "max_balance": None, "fees": 0, "currency": "TTD"},
    {"product_id": 8, "product_name": "Car Loan", "product_type": "Loan", "interest_rate": 8, "min_balance": 5000, "max_balance": 500000, "fees": 0, "currency": "TTD"},
    {"product_id": 9, "product_name": "Retirement Account", "product_type": "Deposit", "interest_rate": 3.5, "min_balance": 1000, "max_balance": None, "fees": 0, "currency": "TTD"}
]

products_df = pd.DataFrame(products)
display(products_df)
# Out:
#    product_id             product_name product_type  interest_rate  \
# 0           1    Basic Savings Account      Deposit            1.5
# 1           2  Premium Savings Account      Deposit            2.0
# 2           3         Checking Account      Deposit            0.5
# 3           4            Personal Loan         Loan           10.0
# 4           5                Home Loan         Loan            7.0
# 5           6              Credit Card       Credit           18.0
# 6           7       Investment Account   Investment            5.0
# 7           8                 Car Loan         Loan            8.0
# 8           9       Retirement Account      Deposit            3.5
#
#    min_balance  max_balance  fees currency
# 0           50          NaN    10      TTD
# 1         5000          NaN    20      TTD
# 2            0          NaN    15      TTD
# 3         1000     200000.0     0      TTD
# 4        50000    1000000.0     0      TTD
# ...

# %%
file_name = "banking_products.csv"

products_df.to_csv(file_name, index=False)
